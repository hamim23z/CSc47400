# %% [markdown]
# <a href="https://colab.research.google.com/github/hamim23z/CSc47400/blob/main/CSC47400_HW1_Problem3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from IPython.display import Image, display, Markdown

# %%
base_path = "/content/drive/My Drive/Datasets/Images/"

# %%
#1D Time Series
display(Image(filename=base_path + "1d_time_series.png", width=600))
display(Markdown("""
**1D Time Series**
The plot shows the number of airline passengers over time. The passenger count is indexed by time.
In a time series, values are ordered and measured at regular time intervals. Here,
passenger counts change every month
"""))
# Out:
# **1D Time Series**
# The plot shows the number of airline passengers over time. The passenger count is indexed by time.
# In a time series, values are ordered and measured at regular time intervals. Here,
# passenger counts change every month

# %%
#2D Scalar Field
display(Image(filename=base_path + "2d_Scalar.jpg", width=600))
display(Markdown("""
**2D Scalar Field**
This heatmap shows values distributed across a 2D plane. This plot represents the elevation of Maunga Whau Volcano
Colors and contour lines show scalar values like elevation in meters but here we have a pair of coordinates
North-South and West-East. Red means high elevation and blue means low elevation.
"""))
# Out:
# **2D Scalar Field**
# This heatmap shows values distributed across a 2D plane. This plot represents the elevation of Maunga Whau Volcano
# Colors and contour lines show scalar values like elevation in meters but here we have a pair of coordinates
# North-South and West-East. Red means high elevation and blue means low elevation.

# %%
#3D Scalar Field
display(Image(filename=base_path + "3D_Scalar.png", width=600))
display(Markdown("""
**3D Scalar Field**
This figure shows a scalar field defined in 3D space, where each point has a scalar value.
The scalar field in 3D assigns a single value to every location in three dimensions.
"""))
# Out:
# **3D Scalar Field**
# This figure shows a scalar field defined in 3D space, where each point has a scalar value.
# The scalar field in 3D assigns a single value to every location in three dimensions.

# %%
#2D Vector Field
display(Image(filename=base_path + "2d_Vector_Field.png", width=600))
display(Markdown("""
**2D Vector Field**
This figure shows arrows that represent the vector field x^2 - y^2 - 4. And Vy(x,y)=2xy
In 2d, we have magnitide and direction and that it was the blue arrows represent. This is
primarily shown in Calc 2 and Calc 3 a lot. Also in science too.
"""))
# Out:
# **2D Vector Field**
# This figure shows arrows that represent direction and magnitude of a quantity in 2D.
# Common examples include wind maps, ocean currents, or magnetic field lines on a surface.

# %%
#3D Shape
display(Image(filename=base_path + "3D_Shape_Cube.jpg", width=600))
display(Markdown("""
**3D Shape**
This visualization shows a cube. One of the most common 3d shapes out there. And it is
typically seen everywhere.
"""))
# Out:
# **3D Shape**
# This visualization shows a geometric 3D object.
# Examples include CAD models, 3D scans of objects, or molecular structures.

# %%
#Graph Not Tree
display(Image(filename=base_path + "Graph.png", width=600))
display(Markdown("""
**Graph (not tree)**
This  visualization shows nodes and edges representing relationships. This graph
is not a tree. An undirected graph is a tree if there is no cycle and the graph is connected.
This is not a tree because the graph is connected fully but there is a cycle. But regardless,
not a tree.
"""))
# Out:
# **Graph (not tree)**
# This  visualization shows nodes and edges representing relationships. This graph
# is not a tree. An undirected graph is a tree if there is no cycle and the graph is connected.
# This is not a tree because the graph is connected fully but there is a cycle. But regardless,
# not a tree.
